# %% [markdown]
# ## 1. 数值稳定性

# %% [markdown]
# - 当数值过大或者过小时会导致数值问题
# - 常发生在深度模型中，因为其会对n个数累乘

# %% [markdown]
# ## 2. 让训练更加稳定

# %% [markdown]
# - 目标：让梯度值在合理的范围内
# - 将乘法变加法：ResNet, LSTM
# - 归一化：梯度归一化，梯度裁剪
# - **合理的权重初始化和激活函数**

# %% [markdown]
# 权重初始化：保证每一层权重的均值和方差都保持一致，均值均为0，正向方差均为常数a，反向方差均为常数b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中$n_t$是第$t$层的神经元个数，$\gamma_t$是第$t$层的权重方差

# %% [markdown]
# 另需满足：激活函数$f(x)=x$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# tanh和relu在x较小时近似满足，sigmoid需做一些调整
